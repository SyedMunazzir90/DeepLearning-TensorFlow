# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.8.2'

# %%
import numpy as np
from matplotlib import pyplot as plt

# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

# Visualize it
plt.scatter(X, y);

# %%
X.shape, y.shape, X.ndim, y.ndim
# Out:
# ((8,), (8,), 1, 1)

# %%
tf.expand_dims(X, axis=1)
# Out:
# <tf.Tensor: shape=(8, 1), dtype=float64, numpy=
# array([[-7.],
#        [-4.],
#        [-1.],
#        [ 2.],
#        [ 5.],
#        [ 8.],
#        [11.],
#        [14.]])>

# %%
tf.expand_dims(X, axis=-1)
# Out:
# <tf.Tensor: shape=(8, 1), dtype=float64, numpy=
# array([[-7.],
#        [-4.],
#        [-1.],
#        [ 2.],
#        [ 5.],
#        [ 8.],
#        [11.],
#        [14.]])>

# %%
tf.random.set_seed(42)

model = tf.keras.Sequential([tf.keras.layers.Dense(1)])
model.compile(loss=tf.keras.losses.mae, 
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])
model.fit(tf.expand_dims(X, axis=-1),y, epochs=5)
# Out:
# Epoch 1/5
# 1/1 [==============================] - 3s 3s/step - loss: 11.5048 - mae: 11.5048
# Epoch 2/5
# 1/1 [==============================] - 0s 16ms/step - loss: 11.3723 - mae: 11.3723
# Epoch 3/5
# 1/1 [==============================] - 0s 12ms/step - loss: 11.2398 - mae: 11.2398
# Epoch 4/5
# 1/1 [==============================] - 0s 10ms/step - loss: 11.1073 - mae: 11.1073
# Epoch 5/5
# 1/1 [==============================] - 0s 11ms/step - loss: 10.9748 - mae: 10.9748

# %%
X, y
# Out:
# (array([-7., -4., -1.,  2.,  5.,  8., 11., 14.]),
#  array([ 3.,  6.,  9., 12., 15., 18., 21., 24.]))

# %%
model.predict([17.0])
# Out:
# array([[12.716021]], dtype=float32)

# %%
#Improve the model

model = tf.keras.Sequential([
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics="mae")

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 439ms/step - loss: 18.1223 - mae: 18.1223
# Epoch 2/100
# 1/1 [==============================] - 0s 14ms/step - loss: 17.8410 - mae: 17.8410
# Epoch 3/100
# 1/1 [==============================] - 0s 22ms/step - loss: 17.5598 - mae: 17.5598
# Epoch 4/100
# 1/1 [==============================] - 0s 12ms/step - loss: 17.2785 - mae: 17.2785
# Epoch 5/100
# 1/1 [==============================] - 0s 17ms/step - loss: 16.9973 - mae: 16.9973
# Epoch 6/100
# 1/1 [==============================] - 0s 13ms/step - loss: 16.7160 - mae: 16.7160
# Epoch 7/100
# 1/1 [==============================] - 0s 13ms/step - loss: 16.4348 - mae: 16.4348
# Epoch 8/100
# 1/1 [==============================] - 0s 19ms/step - loss: 16.1535 - mae: 16.1535
# Epoch 9/100
# 1/1 [==============================] - 0s 19ms/step - loss: 15.8723 - mae: 15.8723
# Epoch 10/100
# 1/1 [==============================] - 0s 16ms/step - loss: 15.5910 - mae: 15.5910
# Epoch 11/100
# 1/1 [==============================] - 0s 15ms/step - loss: 15.3098 - mae: 15.3098
# Epoch 12/100
# 1/1 [==============================] - 0s 12ms/step - loss: 15.0285 - mae: 15.0285
# Epoch 13/100
# 1/1 [==============================] - 0s 13ms/step - loss: 14.7865 - mae: 14.7865
# Epoch 14/100
# 1/1 [==============================] - 0s 14ms/step - loss: 14.6540 - mae: 14.6540
# Epoch 15/100
# 1/1 [==============================] - 0s 13ms/step - loss: 14.5215 - mae: 14.5215
# Epoch 16/100
# 1/1 [==============================] - 0s 12ms/step - loss: 14.3890 - mae: 14.3890
# Epoch 17/100
# 1/1 [==============================] - 0s 23ms/step - loss: 14.2565 - mae: 14.2565
# Epoch 18/100
# 1/1 [==============================] - 0s 13ms/step - loss: 14.1240 - mae: 14.1240
# Epoch 19/100
# 1/1 [==============================] - 0s 17ms/step - loss: 13.9915 - mae: 13.9915
# Epoch 20/100
# 1/1 [==============================] - 0s 12ms/step - loss: 13.8590 - mae: 13.8590
# Epoch 21/100
# 1/1 [==============================] - 0s 13ms/step - loss: 13.7265 - mae: 13.7265
# Epoch 22/100
# 1/1 [==============================] - 0s 26ms/step - loss: 13.5940 - mae: 13.5940
# Epoch 23/100
# 1/1 [==============================] - 0s 8ms/step - loss: 13.4615 - mae: 13.4615
# Epoch 24/100
# 1/1 [==============================] - 0s 9ms/step - loss: 13.3290 - mae: 13.3290
# Epoch 25/100
# 1/1 [==============================] - 0s 19ms/step - loss: 13.1965 - mae: 13.1965
# Epoch 26/100
# 1/1 [==============================] - 0s 6ms/step - loss: 13.0640 - mae: 13.0640
# Epoch 27/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.9315 - mae: 12.9315
# Epoch 28/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.7990 - mae: 12.7990
# Epoch 29/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.6665 - mae: 12.6665
# Epoch 30/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.5340 - mae: 12.5340
# Epoch 31/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.4015 - mae: 12.4015
# Epoch 32/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.2690 - mae: 12.2690
# Epoch 33/100
# 1/1 [==============================] - 0s 6ms/step - loss: 12.1365 - mae: 12.1365
# Epoch 34/100
# 1/1 [==============================] - 0s 7ms/step - loss: 12.0040 - mae: 12.0040
# Epoch 35/100
# 1/1 [==============================] - 0s 17ms/step - loss: 11.8715 - mae: 11.8715
# Epoch 36/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.7390 - mae: 11.7390
# Epoch 37/100
# 1/1 [==============================] - 0s 14ms/step - loss: 11.6065 - mae: 11.6065
# Epoch 38/100
# 1/1 [==============================] - 0s 15ms/step - loss: 11.4740 - mae: 11.4740
# Epoch 39/100
# 1/1 [==============================] - 0s 10ms/step - loss: 11.3415 - mae: 11.3415
# Epoch 40/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.2090 - mae: 11.2090
# Epoch 41/100
# 1/1 [==============================] - 0s 11ms/step - loss: 11.0765 - mae: 11.0765
# Epoch 42/100
# 1/1 [==============================] - 0s 11ms/step - loss: 10.9440 - mae: 10.9440
# Epoch 43/100
# 1/1 [==============================] - 0s 5ms/step - loss: 10.8115 - mae: 10.8115
# Epoch 44/100
# 1/1 [==============================] - 0s 8ms/step - loss: 10.6790 - mae: 10.6790
# Epoch 45/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.5465 - mae: 10.5465
# Epoch 46/100
# 1/1 [==============================] - 0s 10ms/step - loss: 10.4140 - mae: 10.4140
# Epoch 47/100
# 1/1 [==============================] - 0s 6ms/step - loss: 10.2815 - mae: 10.2815
# Epoch 48/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.1490 - mae: 10.1490
# Epoch 49/100
# 1/1 [==============================] - 0s 7ms/step - loss: 10.0165 - mae: 10.0165
# Epoch 50/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.8840 - mae: 9.8840
# Epoch 51/100
# 1/1 [==============================] - 0s 7ms/step - loss: 9.7515 - mae: 9.7515
# Epoch 52/100
# 1/1 [==============================] - 0s 11ms/step - loss: 9.6190 - mae: 9.6190
# Epoch 53/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.4865 - mae: 9.4865
# Epoch 54/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.3540 - mae: 9.3540
# Epoch 55/100
# 1/1 [==============================] - 0s 9ms/step - loss: 9.2215 - mae: 9.2215
# Epoch 56/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.0890 - mae: 9.0890
# Epoch 57/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.9565 - mae: 8.9565
# Epoch 58/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.8240 - mae: 8.8240
# Epoch 59/100
# 1/1 [==============================] - 0s 9ms/step - loss: 8.6915 - mae: 8.6915
# Epoch 60/100
# 1/1 [==============================] - 0s 14ms/step - loss: 8.5590 - mae: 8.5590
# Epoch 61/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.4265 - mae: 8.4265
# Epoch 62/100
# 1/1 [==============================] - 0s 10ms/step - loss: 8.2940 - mae: 8.2940
# Epoch 63/100
# 1/1 [==============================] - 0s 13ms/step - loss: 8.1615 - mae: 8.1615
# Epoch 64/100
# 1/1 [==============================] - 0s 11ms/step - loss: 8.0290 - mae: 8.0290
# Epoch 65/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.8965 - mae: 7.8965
# Epoch 66/100
# 1/1 [==============================] - 0s 15ms/step - loss: 7.7640 - mae: 7.7640
# Epoch 67/100
# 1/1 [==============================] - 0s 18ms/step - loss: 7.6315 - mae: 7.6315
# Epoch 68/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.4990 - mae: 7.4990
# Epoch 69/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.3665 - mae: 7.3665
# Epoch 70/100
# 1/1 [==============================] - 0s 9ms/step - loss: 7.2340 - mae: 7.2340
# Epoch 71/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.1015 - mae: 7.1015
# Epoch 72/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9900 - mae: 6.9900
# Epoch 73/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9844 - mae: 6.9844
# Epoch 74/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.9788 - mae: 6.9788
# Epoch 75/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.9731 - mae: 6.9731
# Epoch 76/100
# 1/1 [==============================] - 0s 13ms/step - loss: 6.9675 - mae: 6.9675
# Epoch 77/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9619 - mae: 6.9619
# Epoch 78/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.9563 - mae: 6.9563
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9506 - mae: 6.9506
# Epoch 80/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.9450 - mae: 6.9450
# Epoch 81/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9394 - mae: 6.9394
# Epoch 82/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9338 - mae: 6.9338
# Epoch 83/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.9281 - mae: 6.9281
# Epoch 84/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.9225 - mae: 6.9225
# Epoch 85/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.9169 - mae: 6.9169
# Epoch 86/100
# 1/1 [==============================] - 0s 18ms/step - loss: 6.9113 - mae: 6.9113
# Epoch 87/100
# 1/1 [==============================] - 0s 14ms/step - loss: 6.9056 - mae: 6.9056
# Epoch 88/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9000 - mae: 6.9000
# Epoch 89/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8944 - mae: 6.8944
# Epoch 90/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.8888 - mae: 6.8888
# Epoch 91/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8831 - mae: 6.8831
# Epoch 92/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8775 - mae: 6.8775
# Epoch 93/100
# 1/1 [==============================] - 0s 10ms/step - loss: 6.8719 - mae: 6.8719
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 6.8663 - mae: 6.8663
# Epoch 95/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.8606 - mae: 6.8606
# Epoch 96/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8550 - mae: 6.8550
# Epoch 97/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8494 - mae: 6.8494
# Epoch 98/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8438 - mae: 6.8438
# Epoch 99/100
# 1/1 [==============================] - 0s 6ms/step - loss: 6.8381 - mae: 6.8381
# Epoch 100/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8325 - mae: 6.8325

# %%
model.predict([17.0])
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fdf45bd8170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# array([[29.316553]], dtype=float32)

# %%
# Create features
X = np.array([-7.0, -4.0, -1.0, 2.0, 5.0, 8.0, 11.0, 14.0])

# Create labels
y = np.array([3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0])

model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation=None),
    tf.keras.layers.Dense(1)
])

model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.Adam(lr=0.01),
              metrics="mae")

model.fit(tf.expand_dims(X, axis=-1), y, epochs=100)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 423ms/step - loss: 12.4420 - mae: 12.4420
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 11.4606 - mae: 11.4606
# Epoch 3/100
# 1/1 [==============================] - 0s 11ms/step - loss: 10.4611 - mae: 10.4611
# Epoch 4/100
# 1/1 [==============================] - 0s 10ms/step - loss: 9.4369 - mae: 9.4369
# Epoch 5/100
# 1/1 [==============================] - 0s 7ms/step - loss: 8.3819 - mae: 8.3819
# Epoch 6/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.2904 - mae: 7.2904
# Epoch 7/100
# 1/1 [==============================] - 0s 7ms/step - loss: 6.8861 - mae: 6.8861
# Epoch 8/100
# 1/1 [==============================] - 0s 7ms/step - loss: 7.3107 - mae: 7.3107
# Epoch 9/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.6041 - mae: 7.6041
# Epoch 10/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.6292 - mae: 7.6292
# Epoch 11/100
# 1/1 [==============================] - 0s 8ms/step - loss: 7.3570 - mae: 7.3570
# Epoch 12/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.9920 - mae: 6.9920
# Epoch 13/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.6460 - mae: 6.6460
# Epoch 14/100
# 1/1 [==============================] - 0s 9ms/step - loss: 6.2735 - mae: 6.2735
# Epoch 15/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1593 - mae: 6.1593
# Epoch 16/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.2511 - mae: 6.2511
# Epoch 17/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3627 - mae: 6.3627
# Epoch 18/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.3191 - mae: 6.3191
# Epoch 19/100
# 1/1 [==============================] - 0s 8ms/step - loss: 6.1423 - mae: 6.1423
# Epoch 20/100
# 1/1 [==============================] - 0s 21ms/step - loss: 5.8468 - mae: 5.8468
# Epoch 21/100
# 1/1 [==============================] - 0s 8ms/step - loss: 5.5360 - mae: 5.5360
# Epoch 22/100
# 1/1 [==============================] - 0s 9ms/step - loss: 5.3883 - mae: 5.3883
# Epoch 23/100
# 1/1 [==============================] - 0s 16ms/step - loss: 5.3322 - mae: 5.3322
# Epoch 24/100
# 1/1 [==============================] - 0s 10ms/step - loss: 5.3165 - mae: 5.3165
# Epoch 25/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5.2364 - mae: 5.2364
# Epoch 26/100
# 1/1 [==============================] - 0s 12ms/step - loss: 5.0967 - mae: 5.0967
# Epoch 27/100
# 1/1 [==============================] - 0s 12ms/step - loss: 4.9024 - mae: 4.9024
# Epoch 28/100
# 1/1 [==============================] - 0s 10ms/step - loss: 4.6583 - mae: 4.6583
# Epoch 29/100
# 1/1 [==============================] - 0s 20ms/step - loss: 4.4118 - mae: 4.4118
# Epoch 30/100
# 1/1 [==============================] - 0s 8ms/step - loss: 4.2710 - mae: 4.2710
# Epoch 31/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.1165 - mae: 4.1165
# Epoch 32/100
# 1/1 [==============================] - 0s 9ms/step - loss: 4.0665 - mae: 4.0665
# Epoch 33/100
# 1/1 [==============================] - 0s 17ms/step - loss: 3.8418 - mae: 3.8418
# Epoch 34/100
# 1/1 [==============================] - 0s 19ms/step - loss: 3.5222 - mae: 3.5222
# Epoch 35/100
# 1/1 [==============================] - 0s 12ms/step - loss: 3.2812 - mae: 3.2812
# Epoch 36/100
# 1/1 [==============================] - 0s 10ms/step - loss: 3.1457 - mae: 3.1457
# Epoch 37/100
# 1/1 [==============================] - 0s 10ms/step - loss: 2.9673 - mae: 2.9673
# Epoch 38/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.7082 - mae: 2.7082
# Epoch 39/100
# 1/1 [==============================] - 0s 13ms/step - loss: 2.3714 - mae: 2.3714
# Epoch 40/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.0151 - mae: 2.0151
# Epoch 41/100
# 1/1 [==============================] - 0s 10ms/step - loss: 1.8221 - mae: 1.8221
# Epoch 42/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.4979 - mae: 1.4979
# Epoch 43/100
# 1/1 [==============================] - 0s 27ms/step - loss: 1.0924 - mae: 1.0924
# Epoch 44/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.8206 - mae: 0.8206
# Epoch 45/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.3811 - mae: 0.3811
# Epoch 46/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1680 - mae: 0.1680
# Epoch 47/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4783 - mae: 0.4783
# Epoch 48/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.7201 - mae: 0.7201
# Epoch 49/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.7900 - mae: 0.7900
# Epoch 50/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.9346 - mae: 0.9346
# Epoch 51/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.9371 - mae: 0.9371
# Epoch 52/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.9238 - mae: 0.9238
# Epoch 53/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.8190 - mae: 0.8190
# Epoch 54/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.7228 - mae: 0.7228
# Epoch 55/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.5513 - mae: 0.5513
# Epoch 56/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.4704 - mae: 0.4704
# Epoch 57/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.1958 - mae: 0.1958
# Epoch 58/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3539 - mae: 0.3539
# Epoch 59/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4191 - mae: 0.4191
# Epoch 60/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4212 - mae: 0.4212
# Epoch 61/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5987 - mae: 0.5987
# Epoch 62/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5452 - mae: 0.5452
# Epoch 63/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.5709 - mae: 0.5709
# Epoch 64/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.5075 - mae: 0.5075
# Epoch 65/100
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4685 - mae: 0.4685
# Epoch 66/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.3703 - mae: 0.3703
# Epoch 67/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2112 - mae: 0.2112
# Epoch 68/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.1028 - mae: 0.1028
# Epoch 69/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3617 - mae: 0.3617
# Epoch 70/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4563 - mae: 0.4563
# Epoch 71/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.3199 - mae: 0.3199
# Epoch 72/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5712 - mae: 0.5712
# Epoch 73/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.6277 - mae: 0.6277
# Epoch 74/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.3332 - mae: 0.3332
# Epoch 75/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.3738 - mae: 0.3738
# Epoch 76/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5583 - mae: 0.5583
# Epoch 77/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.3623 - mae: 0.3623
# Epoch 78/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.2798 - mae: 0.2798
# Epoch 79/100
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5038 - mae: 0.5038
# Epoch 80/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4260 - mae: 0.4260
# Epoch 81/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1252 - mae: 0.1252
# Epoch 82/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.6090 - mae: 0.6090
# Epoch 83/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.7585 - mae: 0.7585
# Epoch 84/100
# 1/1 [==============================] - 0s 7ms/step - loss: 0.5493 - mae: 0.5493
# Epoch 85/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.1380 - mae: 0.1380
# Epoch 86/100
# 1/1 [==============================] - 0s 9ms/step - loss: 0.5821 - mae: 0.5821
# Epoch 87/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7010 - mae: 0.7010
# Epoch 88/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4555 - mae: 0.4555
# Epoch 89/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1973 - mae: 0.1973
# Epoch 90/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4165 - mae: 0.4165
# Epoch 91/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.3244 - mae: 0.3244
# Epoch 92/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1433 - mae: 0.1433
# Epoch 93/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.2700 - mae: 0.2700
# Epoch 94/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1320 - mae: 0.1320
# Epoch 95/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2353 - mae: 0.2353
# Epoch 96/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2242 - mae: 0.2242
# Epoch 97/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1588 - mae: 0.1588
# Epoch 98/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1795 - mae: 0.1795
# Epoch 99/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1838 - mae: 0.1838
# Epoch 100/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.1737 - mae: 0.1737

# %%
model.predict([17.0])
# Out:
# array([[26.68491]], dtype=float32)

# %%
#Evaluate the model

# Make a bigger dataset
X = np.arange(-100, 100, 4)
X
# Out:
# array([-100,  -96,  -92,  -88,  -84,  -80,  -76,  -72,  -68,  -64,  -60,
#         -56,  -52,  -48,  -44,  -40,  -36,  -32,  -28,  -24,  -20,  -16,
#         -12,   -8,   -4,    0,    4,    8,   12,   16,   20,   24,   28,
#          32,   36,   40,   44,   48,   52,   56,   60,   64,   68,   72,
#          76,   80,   84,   88,   92,   96])

# %%
# Make labels for the dataset (adhering to the same pattern as before)
y = np.arange(-90, 110, 4)
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Same result as above
y = X + 10
y
# Out:
# array([-90, -86, -82, -78, -74, -70, -66, -62, -58, -54, -50, -46, -42,
#        -38, -34, -30, -26, -22, -18, -14, -10,  -6,  -2,   2,   6,  10,
#         14,  18,  22,  26,  30,  34,  38,  42,  46,  50,  54,  58,  62,
#         66,  70,  74,  78,  82,  86,  90,  94,  98, 102, 106])

# %%
# Check how many samples we have
len(X)
# Out:
# 50

# %%
# Split data into train and test sets
X_train = X[:40] # first 40 examples (80% of data)
y_train = y[:40]

X_test = X[40:] # last 10 examples (20% of data)
y_test = y[40:]

len(X_train), len(X_test)
# Out:
# (40, 10)

# %%
plt.figure(figsize=(10, 7))
# Plot training data in blue
plt.scatter(X_train, y_train, c='b', label='Training data')
# Plot test data in green
plt.scatter(X_test, y_test, c='g', label='Testing data')
# Show the legend
plt.legend();

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1)
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit model (same as above)
#model.fit(X_train, y_train, epochs=100) # commented out on purpose (not fitting it just yet)

# %%
model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5f15418b3570> in <module>
# ----> 1 model.summary()
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in summary(self, line_length, positions, print_fn, expand_nested, show_trainable)
#    2774     if not self.built:
#    2775       raise ValueError(
# -> 2776           'This model has not yet been built. '
#    2777           'Build the model first by calling `build()` or by calling '
#    2778           'the model on a batch of data.')
#
# ValueError: This model has not yet been built. Build the model first by calling `build()` or by calling the model on a batch of data.

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(3, input_shape=[1])
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit model (same as above)
#model.fit(X_train, y_train, epochs=100) # commented out on purpose (not fitting it just yet)

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 3)                 6
#
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set random seed
tf.random.set_seed(42)

# Create a model (same as above)
model = tf.keras.Sequential([
  tf.keras.layers.Dense(1, input_shape=[1])
])

# Compile model (same as above)
model.compile(loss=tf.keras.losses.mae,
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["mae"])

# Fit model (same as above)
#model.fit(X_train, y_train, epochs=100) # commented out on purpose (not fitting it just yet)

model.summary()
# Out:
# Model: "sequential_38"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_64 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
